# %%
from chatbot import *

# %%
ins = Chatbot("svc", True)
# Out:
# data set loaded successfully, dataset size = 58

# %%
ins.train()
# Out:
# Default parameters are set
# c:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Accuracy: 0.3148148148148148, F1: 0.24000000000000002, Recall: 0.32380952380952377, Precision: 0.23530612244897958
